# %%
#Shreya Singh

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-124ccdd4-ad7d-41b3-8a22-8b971d7dffcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-124ccdd4-ad7d-41b3-8a22-8b971d7dffcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'untitled1.py',
#  'plot_tokens_vocab1.py',
#  'preprocess.py',
#  'analyze_text1.py',
#  'print_tokens_vocab.py',
#  'sample_data']

# %%
# !pip install nltk matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gdown

# %%
import gdown

# Google Drive file ID
file_id = '1PVA5IR4bAn7RulAeuSgxRBNMtmRGXaUm'
# Output file name
output = '/content/your_file.zip'

# Download the file
gdown.download(f'https://drive.google.com/uc?id={file_id}', output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PVA5IR4bAn7RulAeuSgxRBNMtmRGXaUm
# From (redirected): https://drive.google.com/uc?id=1PVA5IR4bAn7RulAeuSgxRBNMtmRGXaUm&confirm=t&uuid=43e1d3eb-cc29-4d46-9084-c516139bea41
# To: /content/your_file.zip
# 100%|██████████| 1.00G/1.00G [00:22<00:00, 43.9MB/s]
# '/content/your_file.zip'

# %%
# !file /content/your_file.zip
# Out:
# /content/your_file.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
import zipfile
import os

# Directory where the ZIP file will be extracted
extract_dir = '/content/your_extracted_folder'

# Create the directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Path to the ZIP file
zip_file_path = '/content/your_file.zip'

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List extracted files to verify
os.listdir(extract_dir)
# Out:
# ['pdf_json']

# %%
import os

# List files in the 'pdf_json' directory
pdf_json_dir = '/content/your_extracted_folder/pdf_json'
os.listdir(pdf_json_dir)
# Out:
# ['0b67e259fd64cd00d911f3f78b16e5c9c5fa04ab.json',
#  '375b438ae6250e39e16ed60349f924b2693f1d25.json',
#  '11a490252c383e450c08ebab44f551a1cdaf80b8.json',
#  '63f3dbec0f5c2d13e98dcbca95824db0fcbf5c73.json',
#  '0dea3dbd3c3150c866cb699f059bc90b92f8eafb.json',
#  '2f1ae15937513f5664cf67120252a5d450f985cc.json',
#  '2ec1374c7cede3b7697309710a09033b581562b5.json',
#  '3acbd6e6bb0e683cf6818c1ac8e761d9ac9911d8.json',
#  '43d4ca7da86537799185698ae3463b736bc56fc1.json',
#  '677a68a1361f16696b72fd73e27d7614ee609d4b.json',
#  '25c1785f7aa54f85cb2ae72df2981e81ffe6be3f.json',
#  '58877118af21aa7ad7635102d6d4310c679b9b1f.json',
#  '0a6bbe4fc686d69aceaa734006da4130dc4a1f07.json',
#  '4f5e61016cc163004558e810c9a86210bd8da5ae.json',
#  '067dc9e7922fa5e3914c0e0594b8b0255e13bf45.json',
#  '36e21a7de890afee546a9a1a1c72d38664714c36.json',
#  '164fed682f989202e3767cb6dc593e6ded33c9b8.json',
#  '5ac544cbe7716772ef9b1e0443d72c0933535508.json',
#  '3668cea8f97212902b791fa560c66b4a539a73f2.json',
# ...

# %%
# !python /content/untitled1.py

# %%
import shutil

# Copy the file from Google Drive to the working directory
src_path = '/content/drive/MyDrive/tokens.pkl'  # Adjust the path if the file is located in a different folder
dest_path = '/content/tokens.pkl'
shutil.copy(src_path, dest_path)
# no need to run preprocess file since tpkens.pkl already generated from local
# machine and uploaded to Google drive and imported here
# Out:
# '/content/tokens.pkl'

# %%
# !python /content/print_tokens_vocab.py
# Out:
# Number of tokens: 134028673
# Size of vocabulary: 2105756

# %%
# !python /content/analyze_text.py
# Out:
# Alpha (Zipf’s Law exponent): 0.06042567735846577

# %%
# !python /content/plot_tokens_vocab_sample.py
# Out:
# ^C
